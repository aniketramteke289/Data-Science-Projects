# %%
import numpy as np
import pandas as pd

# %%
churn = pd.read_csv("C:\\Users\\dell\\Downloads\\customer_churn (1).csv")

# %%
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
newCols = churn.iloc[:,[2,6,8,19]]
newCols
# Out:
#       SeniorCitizen PhoneService InternetService TotalCharges
# 0                 0           No             DSL        29.85
# 1                 0          Yes             DSL       1889.5
# 2                 0          Yes             DSL       108.15
# 3                 0           No             DSL      1840.75
# 4                 0          Yes     Fiber optic       151.65
# ...             ...          ...             ...          ...
# 7038              0          Yes             DSL       1990.5
# 7039              0          Yes     Fiber optic       7362.9
# 7040              0           No             DSL       346.45
# 7041              1          Yes     Fiber optic        306.6
# 7042              0          Yes     Fiber optic       6844.5
#
# [7043 rows x 4 columns]

# %%
selected_rows = churn.iloc[200:1001, : ]

# %%
selected_rows
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 200   9323-HGFWY  Female              0     Yes         No      27
# 201   8544-GOQSH  Female              0      No         No      14
# 202   3363-DTIVD    Male              0     Yes        Yes      71
# 203   7018-WBJNK    Male              0      No        Yes      13
# 204   9142-KZXOP    Male              0      No         No      44
# ...          ...     ...            ...     ...        ...     ...
# 996   6641-XRPSU  Female              0      No         No      34
# 997   1374-DMZUI  Female              1      No         No       4
# 998   2545-LXYVJ    Male              0     Yes         No      72
# 999   3234-VKACU    Male              0      No         No       2
# 1000  8357-EQXFO  Female              0      No         No       7
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 200           Yes            No     Fiber optic                  Yes  ...
# ...

# %%
selected_rows_and_cols = churn.iloc[20:200,1:15]
selected_rows_and_cols
# Out:
#      gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20     Male              1      No         No       1           No
# 21     Male              0     Yes         No      12          Yes
# 22     Male              0      No         No       1          Yes
# 23   Female              0     Yes         No      58          Yes
# 24     Male              0     Yes        Yes      49          Yes
# ..      ...            ...     ...        ...     ...          ...
# 195  Female              0     Yes         No      20          Yes
# 196    Male              0     Yes        Yes      24          Yes
# 197    Male              0      No         No      59          Yes
# 198    Male              0     Yes        Yes      72          Yes
# 199    Male              0      No        Yes       1          Yes
#
#         MultipleLines InternetService       OnlineSecurity  \
# 20   No phone service             DSL                   No
# ...

# %%
churn.head(100)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 95  8637-XJIVR  Female              0      No         No      12          Yes
# 96  9803-FTJCG    Male              0     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male              0      No         No       5          Yes
# 98  3212-KXOCR    Male              0      No         No      52          Yes
# 99  4598-XLKNJ  Female              1     Yes         No      25          Yes
#
# ...

# %%
churn.tail(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %%
churn.tail(1)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 7042          Yes            No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 7042              Yes         Yes         Yes             Yes  Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7042    No
#
# [1 rows x 21 columns]

# %%
churn_tenure_data = churn.sort_values("tenure", ascending = False)
churn_tenure_data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1672  4737-AQCPU    Male              0     Yes        Yes      72
# 193   9680-NIAUV  Female              0     Yes        Yes      72
# 4553  5914-XRFQB    Male              0     Yes         No      72
# 483   5168-MQQCA  Female              0     Yes         No      72
# 3266  0464-WJTKO  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1672          Yes               Yes             DSL                  Yes  ...
# ...

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
condition_a = churn[(churn['tenure'] > 50) & (churn['gender'] == 'Female')]
condition_b = churn[(churn['gender'] == "Male") & (churn['SeniorCitizen'] == 0)]
condition_c = churn[(churn['TechSupport'] == "Yes" ) & (churn['Churn'] == 'No')]
condition_d = churn[(churn['Contract'] == 'Month-to-month') & (churn['Churn'] == 'Yes')]

# %%
condition_a
condition_b
condition_c
condition_d
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %%
count = 0

for index, row in churn.iterrows():
    if row['TechSupport'] == 'Yes' and row['gender'] == 'Male' and row['SeniorCitizen'] == 1:
        count += 1

print("Number of customers getting tech support and are male senior citizens:", count)
# Out:
# Number of customers getting tech support and are male senior citizens: 119

# %% [markdown]
# Module 5: Pandas Case Study

# %%
import pandas as pd
import numpy as np

# %%
def create_DataFrame(keys, values):
    data = {key: value for key, value in zip(keys, values)}
    return pd.DataFrame(data)
keys = ["name","age","city"]
values = [["alice","selena","miley"],[22,23,24],["rio","mumbai","dubai"]]

df = create_DataFrame(keys, values)
print(df)
# Out:
#      name  age    city
# 0   alice   22     rio
# 1  selena   23  mumbai
# 2   miley   24   dubai

# %%
import pandas as pd

def create_dataframe(keys, values):
    data = {key: value for key, value in zip(keys, values)}
    return pd.DataFrame(data)

def concatenate_dataframes(df1, df2):
    concatenated = pd.concat([df1, df2], ignore_index=True)
    return concatenated

keys1 = ["Name", "Age"]
values1 = [["John", "Alice"], [25, 30]]
df1 = create_dataframe(keys1, values1)

keys2 = ["Name", "Age"]
values2 = [["Bob", "Eve"], [35, 40]]
df2 = create_dataframe(keys2, values2)

concatenated_df = concatenate_dataframes(df1, df2)
print(concatenated_df)
# Out:
#     Name  Age
# 0   John   25
# 1  Alice   30
# 2    Bob   35
# 3    Eve   40

# %%
df = pd.read_csv(r'C:\Users\dell\Downloads\python-Datasets (2)\python Datasets\python Datasets\cars (1) (1).csv')
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
def find_highest_correlation(hp):
    df = pd.read_csv(r'C:\Users\dell\Downloads\python-Datasets (2)\python Datasets\python Datasets\cars (1) (1).csv')
    corr_matrix = df.corr()
    highest_corr_column = corr_matrix[hp].idxmax()
    return highest_corr_column
column_name = "mpg"
highest_corr_column = find_highest_correlation(column_name)
print(f"The column with the highest correlation to '{column_name}' is '{highest_corr_column}'.")
# Out:
# The column with the highest correlation to 'mpg' is 'mpg'.
